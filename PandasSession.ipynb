# %% [markdown]
# # Pandas Session

# %%
import pandas as pd

df = pd.read_excel(r'D:\Data.xlsx')
df
# Out:
#               Name            Item  Price      Mobile  Gender     Address  \
# 0      Amit Sharma          Laptop  55000  9876543210    Male       Delhi
# 1       Neha Verma    Mobile Phone  22000  9123456780  Female       Noida
# 2      Rahul Singh      Headphones   2500  9988776655    Male     Gurgaon
# 3      Priya Patel     Smart Watch   7000  9871234560  Female   Ahmedabad
# 4      Ankit Kumar          Tablet  18000  9012345678    Male       Patna
# 5        Sneha Roy          Camera  45000  9098765432  Female     Kolkata
# 6      Rohit Mehta        Keyboard   1500  9823456710    Male      Mumbai
# 7       Pooja Nair           Mouse    800  9765432109  Female       Kochi
# 8      Vikas Gupta         Monitor  12000  9887654321    Male      Jaipur
# 9     Kavita Joshi         Printer   9500  9345678120  Female        Pune
# 10    Suresh Reddy         Speaker   3200  9955667788    Male   Hyderabad
# 11   Anjali Mishra      Power Bank   2000  9870098700  Female      Bhopal
# ...

# %%
df.columns
# Out:
# Index(['Name', 'Item', 'Price', 'Mobile', 'Gender', 'Address',
#        'Distance from House (km)'],
#       dtype='object')

# %%
len(df.columns)
# Out:
# 7

# %%
len(df)
# Out:
# 15

# %%
df.isnull()
# Out:
#      Name   Item  Price  Mobile  Gender  Address  Distance from House (km)
# 0   False  False  False   False   False    False                     False
# 1   False  False  False   False   False    False                     False
# 2   False  False  False   False   False    False                     False
# 3   False  False  False   False   False    False                     False
# 4   False  False  False   False   False    False                     False
# 5   False  False  False   False   False    False                     False
# 6   False  False  False   False   False    False                     False
# 7   False  False  False   False   False    False                     False
# 8   False  False  False   False   False    False                     False
# 9   False  False  False   False   False    False                     False
# 10  False  False  False   False   False    False                     False
# ...

# %%
df.isna()
# Out:
#      Name   Item  Price  Mobile  Gender  Address  Distance from House (km)
# 0   False  False  False   False   False    False                     False
# 1   False  False  False   False   False    False                     False
# 2   False  False  False   False   False    False                     False
# 3   False  False  False   False   False    False                     False
# 4   False  False  False   False   False    False                     False
# 5   False  False  False   False   False    False                     False
# 6   False  False  False   False   False    False                     False
# 7   False  False  False   False   False    False                     False
# 8   False  False  False   False   False    False                     False
# 9   False  False  False   False   False    False                     False
# 10  False  False  False   False   False    False                     False
# ...

# %%
df.isnull().sum()
# Out:
# Name                        0
# Item                        0
# Price                       0
# Mobile                      0
# Gender                      0
# Address                     0
# Distance from House (km)    0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 7 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Name                      15 non-null     object
#  1   Item                      15 non-null     object
#  2   Price                     15 non-null     int64
#  3   Mobile                    15 non-null     int64
#  4   Gender                    15 non-null     object
#  5   Address                   15 non-null     object
#  6   Distance from House (km)  15 non-null     int64
# dtypes: int64(3), object(4)
# memory usage: 972.0+ bytes

# %%
import pandas as pd
df = pd.read_excel(r'D:\Data.xlsx')
df
# Out:
#               Name            Item  Price      Mobile  Gender     Address  \
# 0      Amit Sharma          Laptop  55000  9876543210    Male       Delhi
# 1       Neha Verma    Mobile Phone  22000  9123456780  Female       Noida
# 2      Rahul Singh      Headphones   2500  9988776655    Male     Gurgaon
# 3      Priya Patel     Smart Watch   7000  9871234560  Female   Ahmedabad
# 4      Ankit Kumar          Tablet  18000  9012345678    Male       Patna
# 5        Sneha Roy          Camera  45000  9098765432  Female     Kolkata
# 6      Rohit Mehta        Keyboard   1500  9823456710    Male      Mumbai
# 7       Pooja Nair           Mouse    800  9765432109  Female       Kochi
# 8      Vikas Gupta         Monitor  12000  9887654321    Male      Jaipur
# 9     Kavita Joshi         Printer   9500  9345678120  Female        Pune
# 10    Suresh Reddy         Speaker   3200  9955667788    Male   Hyderabad
# 11   Anjali Mishra      Power Bank   2000  9870098700  Female      Bhopal
# ...

# %%
df.head()
# Out:
#           Name          Item  Price      Mobile  Gender    Address  \
# 0  Amit Sharma        Laptop  55000  9876543210    Male      Delhi
# 1   Neha Verma  Mobile Phone  22000  9123456780  Female      Noida
# 2  Rahul Singh    Headphones   2500  9988776655    Male    Gurgaon
# 3  Priya Patel   Smart Watch   7000  9871234560  Female  Ahmedabad
# 4  Ankit Kumar        Tablet  18000  9012345678    Male      Patna
#
#    Distance from House (km)
# 0                         5
# 1                         8
# 2                        12
# 3                         3
# 4                         6

# %%
df[:]
# Out:
#               Name            Item  Price      Mobile  Gender     Address  \
# 0      Amit Sharma          Laptop  55000  9876543210    Male       Delhi
# 1       Neha Verma    Mobile Phone  22000  9123456780  Female       Noida
# 2      Rahul Singh      Headphones   2500  9988776655    Male     Gurgaon
# 3      Priya Patel     Smart Watch   7000  9871234560  Female   Ahmedabad
# 4      Ankit Kumar          Tablet  18000  9012345678    Male       Patna
# 5        Sneha Roy          Camera  45000  9098765432  Female     Kolkata
# 6      Rohit Mehta        Keyboard   1500  9823456710    Male      Mumbai
# 7       Pooja Nair           Mouse    800  9765432109  Female       Kochi
# 8      Vikas Gupta         Monitor  12000  9887654321    Male      Jaipur
# 9     Kavita Joshi         Printer   9500  9345678120  Female        Pune
# 10    Suresh Reddy         Speaker   3200  9955667788    Male   Hyderabad
# 11   Anjali Mishra      Power Bank   2000  9870098700  Female      Bhopal
# ...

# %%
df[: : -1]
# Out:
#               Name            Item  Price      Mobile  Gender     Address  \
# 14  Arjun Malhotra  Gaming Console  42000  9812345600    Male  Chandigarh
# 13        Rina Das       USB Drive    600  9123987654  Female    Guwahati
# 12    Manish Yadav          Router   2800  9001122334    Male     Lucknow
# 11   Anjali Mishra      Power Bank   2000  9870098700  Female      Bhopal
# 10    Suresh Reddy         Speaker   3200  9955667788    Male   Hyderabad
# 9     Kavita Joshi         Printer   9500  9345678120  Female        Pune
# 8      Vikas Gupta         Monitor  12000  9887654321    Male      Jaipur
# 7       Pooja Nair           Mouse    800  9765432109  Female       Kochi
# 6      Rohit Mehta        Keyboard   1500  9823456710    Male      Mumbai
# 5        Sneha Roy          Camera  45000  9098765432  Female     Kolkata
# 4      Ankit Kumar          Tablet  18000  9012345678    Male       Patna
# 3      Priya Patel     Smart Watch   7000  9871234560  Female   Ahmedabad
# ...

# %%
df.tail()
# Out:
#               Name            Item  Price      Mobile  Gender     Address  \
# 10    Suresh Reddy         Speaker   3200  9955667788    Male   Hyderabad
# 11   Anjali Mishra      Power Bank   2000  9870098700  Female      Bhopal
# 12    Manish Yadav          Router   2800  9001122334    Male     Lucknow
# 13        Rina Das       USB Drive    600  9123987654  Female    Guwahati
# 14  Arjun Malhotra  Gaming Console  42000  9812345600    Male  Chandigarh
#
#     Distance from House (km)
# 10                        11
# 11                         5
# 12                         6
# 13                         4
# 14                        13

# %%
df.shape
# Out:
# (15, 7)

# %%
df[3:13]
# Out:
#              Name         Item  Price      Mobile  Gender    Address  \
# 3     Priya Patel  Smart Watch   7000  9871234560  Female  Ahmedabad
# 4     Ankit Kumar       Tablet  18000  9012345678    Male      Patna
# 5       Sneha Roy       Camera  45000  9098765432  Female    Kolkata
# 6     Rohit Mehta     Keyboard   1500  9823456710    Male     Mumbai
# 7      Pooja Nair        Mouse    800  9765432109  Female      Kochi
# 8     Vikas Gupta      Monitor  12000  9887654321    Male     Jaipur
# 9    Kavita Joshi      Printer   9500  9345678120  Female       Pune
# 10   Suresh Reddy      Speaker   3200  9955667788    Male  Hyderabad
# 11  Anjali Mishra   Power Bank   2000  9870098700  Female     Bhopal
# 12   Manish Yadav       Router   2800  9001122334    Male    Lucknow
#
#     Distance from House (km)
# 3                          3
# 4                          6
# 5                         10
# 6                          4
# 7                          2
# ...

# %%
pd.__version__
# Out:
# '2.2.3'

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame
