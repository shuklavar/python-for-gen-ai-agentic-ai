# %%
5
# Out:
# 5

# %%
10.2
# Out:
# 10.2

# %% [markdown]
# # work with string

# %%
'VARUNAKAR'
# Out:
# 'VARUNAKAR'

# %%
"VARUNAKAR"
# Out:
# 'VARUNAKAR'

# %%
'''VARUNAKAR'''
# Out:
# 'VARUNAKAR'

# %%
'''VARUNAKAR
  Shukla'''
# Out:
# 'VARUNAKAR\n  Shukla'

# %% [markdown]
# # Basic string completed

# %% [markdown]
# # 28/11/2025

# %%
v=5
v
# Out:
# 5

# %%
id(v)
# Out:
# 140716662305832

# %%
nit=5;
NIT # CASE sensative

# %%
nit
# Out:
# 5

# %%
8=nit
nit
# Out:
#   Cell In[13], line 1
#     8=nit
#     ^
# SyntaxError: cannot assign to literal here. Maybe you meant '==' instead of '='?

# %% [markdown]
# #variable does not start with digit

# %%
nit8=10
nit8
# Out:
# 10

# %%
def=5
def
# Out:
#   Cell In[15], line 1
#     def=5
#        ^
# SyntaxError: invalid syntax

# %%
DEF =5
DEF
# Out:
# 5

# %%
if=50
if
# Out:
#   Cell In[17], line 1
#     if=50
#       ^
# SyntaxError: invalid syntax

# %%
If =50
If
# Out:
# 50

# %% [markdown]
# - variable are case sensative
# - keyword are not define var
# - special charcater not allowed
# - variable does not start with dighit
# - only _ allowed
#   # python variable completed
#
#   # Data types in python
#   - int
#   - float
#   - bool
#   - complex
#   - string

# %%
3+4
7 +7
4 -1
# Out:
# 3

# %%
print(3+4)
print(7+7)
print(4-1)
# Out:
# 7
# 14
# 3

# %%
5
# Out:
# 5

# %%
7
# Out:
# 7

# %%
_
# Out:
# 7

# %%
_+
# Out:
#   Cell In[29], line 1
#     _+
#       ^
# SyntaxError: invalid syntax

# %% [markdown]
# # 1st dataype in python

# %%
5

# %%
type(5)
# Out:
# int

# %%
7.2

# %%
type(7.2)
# Out:
# float

# %%
f1= 1e0
f1
# Out:
# 1.0

# %%
f1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 f1
#
# NameError: name 'f1' is not defined

# %%
f2= 1e2
f2
# Out:
# 100.0

# %%
type(f2)
# Out:
# float

# %%
f3= 2.3e3
f3
# Out:
# 2300.0

# %%
b=True
b
# Out:
# True

# %%
b=True
b1= False
b+b1
# Out:
# 1

# %%
print(b+b1)
print(b-b1)
print(b*b1)
# Out:
# 1
# 1
# 0

# %%
False/True
# Out:
# 0.0

# %%
False/True
# Out:
# 0.0

# %%
True/False
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[47], line 1
# ----> 1 True/False
#
# ZeroDivisionError: division by zero

# %%
c= 1+2j
c
# Out:
# (1+2j)

# %%
type(c)
# Out:
# complex

# %%
c.imag
# Out:
# 2.0

# %%
c.real
# Out:
# 1.0

# %% [markdown]
# # string indexng
# - forward indexing- always begin with 0 indexing
# - backward indexing always start with -1
# - : print all the element
# - 2: print from 2nd index
# - :5 print value from start index from n-1

# %%
s='prakash'
s
# Out:
# 'prakash'

# %%
s[2:]
# Out:
# 'akash'

# %%
s[:4]
# Out:
# 'prak'

# %%
s[0:6:2]
# Out:
# 'paa'

# %%
s[2: -2]
# Out:
# 'aka'

# %%
movie= '''KGF Chapter 1 – Story Summary
Main Character: Rocky (Yash)
Plot:

The movie starts with Rocky, a poor boy from Mumbai, who dreams of becoming the richest and most powerful man.

He works for the Mumbai mafia and becomes a strong fighter.

He gets a contract to go to KGF – Kolar Gold Fields, a dangerous gold mine controlled by a cruel ruler Garuda.

At KGF, thousands of laborers are treated like slaves.

Rocky’s mission is to kill Garuda, but he slowly becomes a savior for the workers.

The movie ends with Rocky killing Garuda and becoming a hero.'''

movie
# Out:
# 'KGF Chapter 1 – Story Summary\nMain Character: Rocky (Yash)\nPlot:\n\nThe movie starts with Rocky, a poor boy from Mumbai, who dreams of becoming the richest and most powerful man.\n\nHe works for the Mumbai mafia and becomes a strong fighter.\n\nHe gets a contract to go to KGF – Kolar Gold Fields, a dangerous gold mine controlled by a cruel ruler Garuda.\n\nAt KGF, thousands of laborers are treated like slaves.\n\nRocky’s mission is to kill Garuda, but he slowly becomes a savior for the workers.\n\nThe movie ends with Rocky killing Garuda and becoming a hero.'

# %% [markdown]
# # python typecasting

# %%
int(100.3)
# Out:
# 100

# %%
int(True)
# Out:
# 1

# %%
int(False)
# Out:
# 0

# %%
int("10")
# Out:
# 10

# %%
int('ten')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[67], line 1
# ----> 1 int('ten')
#
# ValueError: invalid literal for int() with base 10: 'ten'

# %% [markdown]
# # other type datatype casting

# %%
float(100)
# Out:
# 100.0

# %%
float(True)
# Out:
# 1.0

# %%
float(False)
# Out:
# 0.0

# %%
float('Eight')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[71], line 1
# ----> 1 float('Eight')
#
# ValueError: could not convert string to float: 'Eight'

# %% [markdown]
# - we can caste other data type to float  except string and complex
# - we can type cast other data type to int except complex and string
# -  more than one paramter also not possible in type casting

# %%
complex(8)
# Out:
# (8+0j)

# %%
complex(8,10)
# Out:
# (8+10j)

# %%
complex(8,10,20)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[75], line 1
# ----> 1 complex(8,10,20)
#
# TypeError: complex() takes at most 2 arguments (3 given)

# %%
str('True')
# Out:
# 'True'

# %%
str(2.3)
# Out:
# '2.3'

# %%
str(2)
# Out:
# '2'

# %%
bool(10)
# Out:
# True

# %%
str(1+2j)
# Out:
# '(1+2j)'

# %%
bool()
# Out:
# False

# %%
bool('nit')
# Out:
# True

# %% [markdown]
# # datastructure
# - list
# - Tuple
# - Sey
# - Dict
# - Range

# %% [markdown]
# # Day-10: Lst

# %%
l=[]
l
# Out:
# []

# %%
type(l)
# Out:
# list

# %%
len(l)
# Out:
# 0

# %%
l.append(10)
l
# Out:
# [10]

# %%
l.append(20)
l.append(30)
l.append(40)
l
# Out:
# [10, 20, 30, 40]

# %%
l1=l.copy()
l1
# Out:
# [10, 20, 30, 40]

# %%
print(l)
print(l1)
# Out:
# [10, 20, 30, 40]
# [10, 20, 30, 40]

# %%
l1.append('hi', 1+2j, 2.3, True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[94], line 1
# ----> 1 l1.append('hi', 1+2j, 2.3, True)
#
# TypeError: list.append() takes exactly one argument (4 given)

# %%
l1.append('hi')
l1.append(1+2j)
l1.append('Prakash')
l1.append(True)
l1
# Out:
# [10, 20, 30, 40, 'hi', (1+2j), 'Prakash', True]

# %%
print(l)
print(l1)
# Out:
# [10, 20, 30, 40]
# [10, 20, 30, 40, 'hi', (1+2j), 'Prakash', True]

# %%
print(len(l))
print(len(l1))
# Out:
# 4
# 8

# %%
l3= [1,2,3,4,5,6,7,8, 'varunakar', 'shukla', 1+2j]
l3
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, 'varunakar', 'shukla', (1+2j)]

# %%
l3.clear()
l3
# Out:
# []

# %%
del l3

# %%
l3
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[107], line 1
# ----> 1 l3
#
# NameError: name 'l3' is not defined

# %%
l.count(20)
# Out:
# 1

# %%
l1
# Out:
# [10, 20, 30, 40, 'hi', (1+2j), 'Prakash', True]

# %%
l[:]
# Out:
# [10, 20, 30, 40]

# %%
l[2:]
# Out:
# [30, 40]

# %%
l[: -1]
# Out:
# [10, 20, 30]

# %%
l
# Out:
# [10, 20, 30, 40]

# %%
l[:: -1]
# Out:
# [40, 30, 20, 10]

# %%
print(l)
print(l1)
# Out:
# [10, 20, 30, 40]
# [10, 20, 30, 40, 'hi', (1+2j), 'Prakash', True]

# %%
l.index(10)
# Out:
# 0

# %%
l.index(20)
# Out:
# 1

# %%
l[0]=100
l
# Out:
# [100, 20, 30, 40]

# %%
l[-1]=1000
l
# Out:
# [100, 20, 30, 1000]

# %%
l2=[]
l2
# Out:
# []

# %%
l2.extend(l1)
l2
# Out:
# [10, 20, 30, 40, 'hi', (1+2j), 'Prakash', True]

# %%
l2.extend(l)
l2
# Out:
# [10,
#  20,
#  30,
#  40,
#  'hi',
#  (1+2j),
#  'Prakash',
#  True,
#  100,
#  20,
#  30,
#  1000,
#  100,
#  20,
#  30,
#  1000]

# %%
l2
# Out:
# [10,
#  20,
#  30,
#  40,
#  'hi',
#  (1+2j),
#  'Prakash',
#  True,
#  100,
#  20,
#  30,
#  1000,
#  100,
#  20,
#  30,
#  1000]

# %%
l.insert(2,7)
l
# Out:
# [100, 20, 7, 30, 1000]

# %%
l1
# Out:
# [10, 20, 30, 40, 'hi', (1+2j), 'Prakash', True]

# %%
for i in l1 : 
    print(i)
# Out:
# 10
# 20
# 30
# 40
# hi
# (1+2j)
# Prakash
# True

# %%
for in in enumerate(l1):
    print(i)
# Out:
# (0, 10)
# (1, 20)
# (2, 30)
# (3, 40)
# (4, 'hi')
# (5, (1+2j))
# (6, 'Prakash')
# (7, True)

# %%
l.pop()
# Out:
# 1000

# %%
l
# Out:
# [100, 20, 7, 30]

# %%
l1
# Out:
# [10, 20, 30, 40, 'hi', 'Prakash', True]

# %%
l1.remove(30)
l1
# Out:
# [10, 20, 40, 'Prakash', True]

# %%
l1
# Out:
# [10, 20, 40, 'Prakash', True]

# %%
l1.reverse()
l1
# Out:
# [True, 'Prakash', 40, 20, 10]

# %%
l1.sort()
l1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[147], line 1
# ----> 1 l1.sort()
#       2 l1
#
# TypeError: '<' not supported between instances of 'str' and 'bool'

# %%
l1.

# %%
all(l)
# Out:
# True

# %%
any(l)
# Out:
# True

# %%
l.append(0)
l
# Out:
# [100, 20, 7, 30, 0, 0]

# %%
all(l)
# Out:
# False

# %% [markdown]
# # Day-11: Tuple in python

# %%
t={}
t
# Out:
# {}

# %%
t1={10,20,30}
t1
# Out:
# {10, 20, 30}

# %%
t1.add(

# %%
Icici={123456789, 'FRHPSE473L',2000}
Icici
# Out:
# {123456789, 2000, 'FRHPSE473L'}

# %%
Icici.remove(2000)

Icici
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[171], line 1
# ----> 1 Icici.remove(2000)
#       3 Icici
#
# KeyError: 2000

# %% [markdown]
# # Day-13: Dictionary in python
