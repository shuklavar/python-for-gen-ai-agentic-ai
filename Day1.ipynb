# %%
5
# Out:
# 5

# %%
10.2
# Out:
# 10.2

# %% [markdown]
# # work with string

# %%
'citiustech'
# Out:
# 'citiustech'

# %%
"citiustech"
# Out:
# 'citiustech'

# %%
'''citiustech'''
# Out:
# 'citiustech'

# %%
'''nareshit
  technology'''
# Out:
# 'nareshit\n  technology'

# %% [markdown]
# # Basic string completed
